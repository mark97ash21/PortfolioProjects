# %%
# Import Libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots we will create

# Read in the data

df = pd.read_csv(r'C:\Users\mark9\Downloads\Portfolio\Projects\4\movies.csv')

# %%
# Lets look at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Let's see if there is any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}'.format(col, pct_missing))
# Out:
# name - 0.0
# rating - 0.010041731872717789
# genre - 0.0
# year - 0.0
# released - 0.0002608242044861763
# score - 0.0003912363067292645
# votes - 0.0003912363067292645
# director - 0.0
# writer - 0.0003912363067292645
# star - 0.00013041210224308815
# country - 0.0003912363067292645
# budget - 0.2831246739697444
# gross - 0.02464788732394366
# company - 0.002217005738132499
# runtime - 0.0005216484089723526

# %%
# Data types for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df2 = df

# %%
# change data type of columns

df2['budget'] = pd.to_numeric(df2['budget'], errors='coerce').fillna(0).astype(int)
df2['gross'] = pd.to_numeric(df2['gross'], errors='coerce').fillna(0).astype(int)

# %%
df2[['budget','gross']]
# Out:
#          budget       gross
# 6663  245000000  2069521700
# 7244  321000000  2048359754
# 7480  260000000  1670727580
# 6653  150000000  1670516444
# 6043  220000000  1518815515
# ...         ...         ...
# 5033    1000000           0
# 7667          0           0
# 3045  200000000 -2147483648
# 7445  356000000 -2147483648
# 5445  237000000 -2147483648
#
# [7668 rows x 2 columns]

# %%
# Create correct Year column

df2['yearcorrect'] = df2['released'].astype(str).str.split().str[2]

df2
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#pd.set_option('display.max_rows', None)

# %%
df2 = df2.sort_values(by='gross', inplace=False, ascending=False)

# %%
df2.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df2
# Out:
#                                             name     rating      genre  year  \
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13     Action  2015
# 7244                      Avengers: Infinity War      PG-13     Action  2018
# 7480                               The Lion King         PG  Animation  2019
# 6653                              Jurassic World      PG-13     Action  2015
# 6043                                The Avengers      PG-13     Action  2012
# ...                                          ...        ...        ...   ...
# 5033                            Loving Annabelle  Not Rated      Drama  2006
# 7667                                   Tee em el        NaN     Horror  2020
# 3045                                     Titanic      PG-13      Drama  1997
# 7445                           Avengers: Endgame      PG-13     Action  2019
# 5445                                      Avatar      PG-13     Action  2009
#
# ...

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df2['budget'], y=df2['gross'])

plt.title('Budget vs Gross Earnings')

plt.ylim(0)

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for Film')

plt.show()

# %%
# Plot budget vs gross using using seaborn

sns.regplot(x='budget', y='gross', data = df2, scatter_kws = {"color":"pink"}, line_kws = {"color":"yellow"})

plt.title('Budget vs Gross Earnings')

plt.ylim(0)

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for Film')
# Out:
# Text(0, 0.5, 'Budget for Film')

# %%
# Let's start looking at correlation

# %%
np.corrcoef(df['budget'],df['gross'])
# Out:
# array([[1.        , 0.68712443],
#        [0.68712443, 1.        ]])

# %%
df3 = df2

# %%
df4 = df3.select_dtypes(include='number')

# %%
df4
# Out:
#       year  score      votes     budget       gross  runtime
# 6663  2015    7.8   876000.0  245000000  2069521700    138.0
# 7244  2018    8.4   897000.0  321000000  2048359754    149.0
# 7480  2019    6.9   222000.0  260000000  1670727580    118.0
# 6653  2015    7.0   593000.0  150000000  1670516444    124.0
# 6043  2012    8.0  1300000.0  220000000  1518815515    143.0
# ...    ...    ...        ...        ...         ...      ...
# 5033  2006    6.3    12000.0    1000000           0     77.0
# 7667  2020    5.7        7.0          0           0    102.0
# 3045  1997    7.8  1100000.0  200000000 -2147483648    194.0
# 7445  2019    8.4   903000.0  356000000 -2147483648    181.0
# 5445  2009    7.8  1100000.0  237000000 -2147483648    162.0
#
# [7668 rows x 6 columns]

# %%
df4.corr(method='pearson') #pearson, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.256331  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.169406  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.573889  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.687124  0.269510
# gross    0.256331  0.169406  0.573889  0.687124  1.000000  0.204177
# runtime  0.120811  0.399451  0.309212  0.269510  0.204177  1.000000

# %%
corr_matrix = df4.corr(method='pearson')

sns.heatmap(corr_matrix, annot =True)

plt.title("Correlation Matrix for Numerical Features")

plt.xlabel("Gross Earnings")

plt.ylabel("Budget for films")

plt.show()

# %%
df3
# Out:
#                                             name     rating      genre  year  \
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13     Action  2015
# 7244                      Avengers: Infinity War      PG-13     Action  2018
# 7480                               The Lion King         PG  Animation  2019
# 6653                              Jurassic World      PG-13     Action  2015
# 6043                                The Avengers      PG-13     Action  2012
# ...                                          ...        ...        ...   ...
# 5033                            Loving Annabelle  Not Rated      Drama  2006
# 7667                                   Tee em el        NaN     Horror  2020
# 3045                                     Titanic      PG-13      Drama  1997
# 7445                           Avengers: Endgame      PG-13     Action  2019
# 5445                                      Avatar      PG-13     Action  2009
#
# ...

# %%
df_numerized = df3

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
# 7480  6194       4      2  2019      1488    6.9   222000.0      1455    1919
# 6653  2969       5      0  2015      1704    7.0   593000.0       517    3568
# 6043  5502       5      0  2012      2472    8.0  1300000.0      1517    2314
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5033  3372       3      6  2006      2392    6.3    12000.0      1563    2397
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
#
# ...

# %%
corr_matrix = df_numerized.corr(method='pearson')

sns.heatmap(corr_matrix, annot =True)

plt.title("Correlation Matrix for Numerical Features")

plt.xlabel("Gross Earnings")

plt.ylabel("Budget for films")

plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score        0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes        0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget       0.020548 -0.081939 -0.334021  0.309212  0.009145  0.055665
# ...

# %%
corr_mat = df_numerized.corr()

corr_pairs = corr_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#                               ...
# yearcorrect  budget         0.300649
#              gross          0.249548
#              company       -0.011060
#              runtime        0.120976
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# budget       genre         -0.334021
# genre        budget        -0.334021
# gross        genre         -0.229534
# genre        gross         -0.229534
#              votes         -0.145307
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# gross        votes          0.573889
# votes        gross          0.573889
# budget       gross          0.687124
# gross        budget         0.687124
# year         yearcorrect    0.990063
# yearcorrect  year           0.990063
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# Votes and Budgets have the highest correlation to gross earnings
